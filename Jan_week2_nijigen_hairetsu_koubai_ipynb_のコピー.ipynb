# %% [markdown]
# <a href="https://colab.research.google.com/github/libra3910/diveintocode-ml/blob/master/Jan_week2_nijigen_hairetsu_koubai_ipynb_%E3%81%AE%E3%82%B3%E3%83%94%E3%83%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 機械学習のための数学授業課題１　２次元配列と勾配問題

# %% [markdown]
# ## 【問題1】1次関数

# %%
import numpy as np

# %%
x = np.arange(-50, 50.1, 0.1)

# %%
y = 1 / 2 * x + 1

# %%
x, y
# Out:
# (array([-50. , -49.9, -49.8, ...,  49.8,  49.9,  50. ]),
#  array([-24.  , -23.95, -23.9 , ...,  25.9 ,  25.95,  26.  ]))

# %% [markdown]
# ## 【問題2】配列の結合

# %%
x = x.reshape(-1,1)
y = y.reshape(-1,1)
xy = np.concatenate([x, y], axis = 1)

# %%
xy
# Out:
# array([[-50.  , -24.  ],
#        [-49.9 , -23.95],
#        [-49.8 , -23.9 ],
#        ...,
#        [ 49.8 ,  25.9 ],
#        [ 49.9 ,  25.95],
#        [ 50.  ,  26.  ]])

# %% [markdown]
# ## 【問題3】勾配を求める

# %%
xa = x[1:]
xb = x[:-1]
ya = y[1:]
yb = y[:-1]

# %%
xys = (xa - xb) / (ya - yb)

# %%
xys
# Out:
# array([[2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.]])

# %% [markdown]
# ## 【問題4】グラフを描く

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x, y)
plt.title("1 linear function ")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.grid(True)

# %%
plt.scatter(x[:-1], xys)
plt.title("x and slope ")
plt.xlabel("x axis")
plt.ylabel("slope")
plt.grid(True)

# %% [markdown]
# ## 【問題5】Pythonの関数化

# %%
def compute_gradient(function, x_range=(-50, 50.1, 0.1)):
    """
    変化量を使い勾配を計算する。
    Parameters
    ----------------
    function : function
      求めたい関数、xのndarrayを入れるとyのndarrayを返すもの。
    x_range : tuple
      np.arange()の引数と同じ方法で範囲を指定する。
    Returns
    ----------------
    array_xy : ndarray, shape(n, 2)
      xとyを結合したもの。nはx_rangeに依存する。
    gradient : ndarray, shape(n-1,)
      関数の勾配。差をとるため要素は1つ減る
    """
    x = np.arange(x_range[0], x_range[1], x_range[2]).reshape(-1,1) 
    y = function(x) # FUNCTIONに与えられた関数を実行
    array_xy = np.concatenate([x, y], axis=1) # x、yを列結合
    gradient = (y[1:]-y[:-1]) / (x[1:]-x[:-1]) # 勾配を求める

    plt.scatter(x, y) # x,yのグラフ描画
    plt.scatter(x[:-1], gradient) # X,勾配のグラフ表示

    return array_xy, gradient

def function1(array_x):
    array_y = array_x**2
    return array_y

def function2(array_x):
    array_y = 2*array_x**2 + 2**array_x
    return array_y

def function3(array_x):
    array_y = np.sin(array_x**0.5)
    return array_y

# y=x**2
array_xy, gradient = compute_gradient(function1)
print( array_xy, gradient)
# y=2x**2 + 2**x
array_xy, gradient = compute_gradient(function2)
print( array_xy, gradient)
# y=sin(x**0.5)
array_xy, gradient = compute_gradient(function3)
print( array_xy, gradient)
# Out:
# [[-50.                  nan]
#  [-49.9                 nan]
#  [-49.8                 nan]
#  ...
#  [ 49.8          0.69880548]
#  [ 49.9          0.70385354]
#  [ 50.           0.70886129]] [[            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  [            nan]
#  
#  [ 5.16815735e-02]
#  [ 5.12826072e-02]
#  [ 5.08822661e-02]
#  [ 5.04805772e-02]
#  [ 5.00775673e-02]]
# <ipython-input-92-87b7f862a959>:36: RuntimeWarning: invalid value encountered in sqrt
#   array_y = np.sin(array_x**0.5)

# %% [markdown]
# ## 【問題6】最小値を求める

# %%
def compute_gradient(function, x_range=(-50, 50.1, 0.1)):
    """
    変化量を使い勾配を計算する。
    Parameters
    ----------------
    function : function
      求めたい関数、xのndarrayを入れるとyのndarrayを返すもの。
    x_range : tuple
      np.arange()の引数と同じ方法で範囲を指定する。
    Returns
    ----------------
    array_xy : ndarray, shape(n, 2)
      xとyを結合したもの。nはx_rangeに依存する。
    gradient : ndarray, shape(n-1,)
      関数の勾配。差をとるため要素は1つ減る
    """
    x = np.arange(x_range[0], x_range[1], x_range[2]).reshape(-1,1) 
    array_y_min, gradient_before, gradient_after = function(x) # FUNCTIONに与えられた関数を実行

    return array_y_min, gradient_before, gradient_after

def function1(array_x):
    array_y = array_x**2
    array_y_min = np.min(array_y)
    array_y_argmin = np.argmin(array_y)
    gradient_before = (array_y[array_y_argmin-1]-array_y[array_y_argmin]) / (array_x[array_y_argmin-1]-array_x[array_y_argmin])
    gradient_after = (array_y[array_y_argmin]-array_y[array_y_argmin+1]) / (array_x[array_y_argmin]-array_x[array_y_argmin+1])
    return array_y_min, gradient_before, gradient_after

def function2(array_x):
    array_y = 2*array_x**2 + 2**array_x
    array_y_min = np.min(array_y)
    array_y_argmin = np.argmin(array_y)
    gradient_before = (array_y[array_y_argmin-1]-array_y[array_y_argmin]) / (array_x[array_y_argmin-1]-array_x[array_y_argmin])
    gradient_after = (array_y[array_y_argmin]-array_y[array_y_argmin+1]) / (array_x[array_y_argmin]-array_x[array_y_argmin+1])
    return array_y_min, gradient_before, gradient_after

def function3(array_x):
    array_y = np.sin(array_x**0.5)
    array_y_min = np.min(array_y)
    array_y_argmin = np.argmin(array_y)
    gradient_before = (array_y[array_y_argmin-1]-array_y[array_y_argmin]) / (array_x[array_y_argmin-1]-array_x[array_y_argmin])
    gradient_after = (array_y[array_y_argmin]-array_y[array_y_argmin+1]) / (array_x[array_y_argmin]-array_x[array_y_argmin+1])
    return array_y_min, gradient_before, gradient_after

# y=x**2
y_min, array_y_before, array_y_after = compute_gradient(function1)
print(y_min, array_y_before, array_y_after)
# y=2x**2 + 2**x
y_min, array_y_before, array_y_after = compute_gradient(function2)
print(y_min, array_y_before, array_y_after)
# y=sin(x**0.5)
y_min, array_y_before, array_y_after = compute_gradient(function3)
print(y_min, array_y_before, array_y_after)
# Out:
# 5.048709793414476e-25 [-0.1] [0.1]
# 0.9505505632959851 [-0.41701833] [0.02482428]
# nan [nan] [nan]
# <ipython-input-105-cd5fe8c4c5f0>:39: RuntimeWarning: invalid value encountered in sqrt
#   array_y = np.sin(array_x**0.5)
